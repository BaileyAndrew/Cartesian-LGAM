# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
from generate_data import generate_Ls, generate_sylvester_data
from proximal_gradient_descent import (
    get_optimizer_oracles,
    proximal_accelerated_gradient,
    project_to_lower_with_positive_diag,
    warm_start
)
from plotting_utilities import get_metrics, patternify_Ls, one_example_prs
from sklearn.metrics import precision_score, recall_score, matthews_corrcoef, auc
import pickle
import warnings
warnings.simplefilter("ignore")

# Prevent Type 3 fonts
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

import time
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tol = 1e-3

# %%
np.random.seed(0)
dims = (25, 25)
sparsity = 0.1
Ls, L_patterns = generate_Ls(dims, sparsity=sparsity)
X = generate_sylvester_data(Ls, normalize=True)

L_init = [np.eye(d) for d in dims]

frobreg = 1/np.prod(dims)**(1/len(dims))
glassoregs = np.logspace(2, -2, 10)

clgam_start = time.time()
Lss, _ = warm_start(X, L_init, glassoregs=glassoregs, dont_warm_start=True, tol=tol)
clgam_end = time.time()
lgam_start = time.time()
Lss_lgam, _ = warm_start(X, L_init, glassoregs=glassoregs, sample_axes={0}, dont_warm_start=True, tol=tol)
lgam_end = time.time()

# %%
print(
    f"***** 25[ER] by 25[ER] *****"
    + f"\n\tCLGAM took on average: {(clgam_end - clgam_start) / glassoregs.shape[0]} seconds"
    + f"\n\tLGAM took on average: {(lgam_end - lgam_start) / glassoregs.shape[0]} seconds"
)
# Out:
# ***** 25[ER] by 25[ER] *****
# 	CLGAM took on average: 0.04902970790863037 seconds
# 	LGAM took on average: 0.024894571304321288 seconds

# %%
np.random.seed(0)
dims = (50, 50)
sparsity = 0.1
Ls, L_patterns = generate_Ls(dims, sparsity=sparsity)
X = generate_sylvester_data(Ls, normalize=True)

L_init = [np.eye(d) for d in dims]

frobreg = 1/np.prod(dims)**(1/len(dims))
glassoregs = np.logspace(2, -2, 10) # (50, 50)

clgam_start = time.time()
Lss, _ = warm_start(X, L_init, glassoregs=glassoregs, dont_warm_start=True, tol=tol)
clgam_end = time.time()
lgam_start = time.time()
Lss_lgam, _ = warm_start(X, L_init, glassoregs=glassoregs, sample_axes={0}, dont_warm_start=True, tol=tol)
lgam_end = time.time()

# %%
print(
    f"***** 50[ER] by 50[ER] *****"
    + f"\n\tCLGAM took on average: {(clgam_end - clgam_start) / glassoregs.shape[0]} seconds"
    + f"\n\tLGAM took on average: {(lgam_end - lgam_start) / glassoregs.shape[0]} seconds"
)
# Out:
# ***** 50[ER] by 50[ER] *****
# 	CLGAM took on average: 0.8294842720031739 seconds
# 	LGAM took on average: 0.21675589084625244 seconds

# %%
np.random.seed(0)
dims = (75, 75)
sparsity = 0.1
Ls, L_patterns = generate_Ls(dims, sparsity=sparsity)
X = generate_sylvester_data(Ls, normalize=True)

L_init = [np.eye(d) for d in dims]

frobreg = 1/np.prod(dims)**(1/len(dims))
glassoregs = np.logspace(2, -2, 10)

clgam_start = time.time()
Lss, _ = warm_start(X, L_init, glassoregs=glassoregs, dont_warm_start=True, tol=tol)
clgam_end = time.time()
lgam_start = time.time()
Lss_lgam, _ = warm_start(X, L_init, glassoregs=glassoregs, sample_axes={0}, dont_warm_start=True, tol=tol)
lgam_end = time.time()

# %%
print(
    f"***** 75[ER] by 75[ER] *****"
    + f"\n\tCLGAM took on average: {(clgam_end - clgam_start) / glassoregs.shape[0]} seconds"
    + f"\n\tLGAM took on average: {(lgam_end - lgam_start) / glassoregs.shape[0]} seconds"
)
# Out:
# ***** 75[ER] by 75[ER] *****
# 	CLGAM took on average: 7.114679002761841 seconds
# 	LGAM took on average: 1.7661792993545533 seconds

# %%
np.random.seed(0)
dims = (100, 100)
sparsity = 0.1
Ls, L_patterns = generate_Ls(dims, sparsity=sparsity)
X = generate_sylvester_data(Ls, normalize=True)

L_init = [np.eye(d) for d in dims]

frobreg = 1/np.prod(dims)**(1/len(dims))
glassoregs = np.logspace(2, -2, 10)

clgam_start = time.time()
Lss, _ = warm_start(X, L_init, glassoregs=glassoregs, dont_warm_start=True, tol=tol)
clgam_end = time.time()
lgam_start = time.time()
Lss_lgam, _ = warm_start(X, L_init, glassoregs=glassoregs, sample_axes={0}, dont_warm_start=True, tol=tol)
lgam_end = time.time()

# %%
print(
    f"***** 100[ER] by 100[ER] *****"
    + f"\n\tCLGAM took on average: {(clgam_end - clgam_start) / glassoregs.shape[0]} seconds"
    + f"\n\tLGAM took on average: {(lgam_end - lgam_start) / glassoregs.shape[0]} seconds"
)
# Out:
# ***** 100[ER] by 100[ER] *****
# 	CLGAM took on average: 33.75852398872375 seconds
# 	LGAM took on average: 8.75700831413269 seconds

# %%
np.random.seed(0)
dims = (100, 100)
sparsity = 0.1
Ls, L_patterns = generate_Ls(dims, sparsity=sparsity)
Ls[0] = np.diag(np.ones(dims[0])) + np.diag(np.ones(dims[0]-1), k=-1)
Ls[1] = np.diag(np.ones(dims[1])) + np.diag(np.ones(dims[1]-1), k=-1)
X = generate_sylvester_data(Ls, normalize=True)

L_init = [np.eye(d) for d in dims]

frobreg = 1/np.prod(dims)**(1/len(dims))
glassoregs = np.logspace(2, -2, 10)

clgam_start = time.time()
Lss, _ = warm_start(X, L_init, glassoregs=glassoregs, dont_warm_start=True, tol=tol)
clgam_end = time.time()
lgam_start = time.time()
Lss_lgam, _ = warm_start(X, L_init, glassoregs=glassoregs, sample_axes={0}, dont_warm_start=True, tol=tol)
lgam_end = time.time()

# %%
print(
    f"***** 100[AR(1)] by 100[AR(1)] *****"
    + f"\n\tCLGAM took on average: {(clgam_end - clgam_start) / glassoregs.shape[0]} seconds"
    + f"\n\tLGAM took on average: {(lgam_end - lgam_start) / glassoregs.shape[0]} seconds"
)
# Out:
# ***** 100[AR(1)] by 100[AR(1)] *****
# 	CLGAM took on average: 36.13781650066376 seconds
# 	LGAM took on average: 7.8704406976699826 seconds

# %%
np.random.seed(0)
dims = (25, 25, 25)
sparsity = 0.1
Ls, L_patterns = generate_Ls(dims, sparsity=sparsity)
X = generate_sylvester_data(Ls, normalize=True)

L_init = [np.eye(d) for d in dims]

frobreg = 1/np.prod(dims)**(1/len(dims))
glassoregs = np.logspace(2, -2, 10)

clgam_start = time.time()
Lss, _ = warm_start(X, L_init, glassoregs=glassoregs, dont_warm_start=True, tol=tol)
clgam_end = time.time()
lgam_start = time.time()
Lss_lgam, _ = warm_start(X, L_init, glassoregs=glassoregs, sample_axes={0, 1}, dont_warm_start=True, tol=tol)
lgam_end = time.time()

# %%
print(
    f"***** 25[ER] by 25[ER] by 25[ER] *****"
    + f"\n\tCLGAM took on average: {(clgam_end - clgam_start) / glassoregs.shape[0]} seconds"
    + f"\n\tLGAM took on average: {(lgam_end - lgam_start) / glassoregs.shape[0]} seconds"
)
# Out:
# ***** 25[ER] by 25[ER] by 25[ER] *****
# 	CLGAM took on average: 2.7748908042907714 seconds
# 	LGAM took on average: 1.1231511116027832 seconds

# %%
np.random.seed(0)
dims = (50, 50, 50)
sparsity = 0.1
Ls, L_patterns = generate_Ls(dims, sparsity=sparsity)
X = generate_sylvester_data(Ls, normalize=True)

L_init = [np.eye(d) for d in dims]

frobreg = 1/np.prod(dims)**(1/len(dims))
glassoregs = np.logspace(2, -2, 10)

clgam_start = time.time()
Lss, _ = warm_start(X, L_init, glassoregs=glassoregs, dont_warm_start=True, tol=tol)
clgam_end = time.time()
lgam_start = time.time()
Lss_lgam, _ = warm_start(X, L_init, glassoregs=glassoregs, sample_axes={0, 1}, dont_warm_start=True, tol=tol)
lgam_end = time.time()

# %%
print(
    f"***** 50[ER] by 50[ER] by 50[ER] *****"
    + f"\n\tCLGAM took on average: {(clgam_end - clgam_start) / glassoregs.shape[0]} seconds"
    + f"\n\tLGAM took on average: {(lgam_end - lgam_start) / glassoregs.shape[0]} seconds"
)
# Out:
# ***** 50[ER] by 50[ER] by 50[ER] *****
# 	CLGAM took on average: 171.8820284128189 seconds
# 	LGAM took on average: 55.322839212417605 seconds

# %%
np.random.seed(0)
dims = (25, 25, 25, 25)
sparsity = 0.1
Ls, L_patterns = generate_Ls(dims, sparsity=sparsity)
X = generate_sylvester_data(Ls, normalize=True)

L_init = [np.eye(d) for d in dims]

frobreg = 1/np.prod(dims)**(1/len(dims))
glassoregs = np.logspace(2, -2, 10)

clgam_start = time.time()
Lss, _ = warm_start(X, L_init, glassoregs=glassoregs, dont_warm_start=True, tol=tol)
clgam_end = time.time()
lgam_start = time.time()
Lss_lgam, _ = warm_start(X, L_init, glassoregs=glassoregs, sample_axes={0, 1, 2}, dont_warm_start=True, tol=tol)
lgam_end = time.time()

# %%
print(
    f"***** 25[ER] by 25[ER] by 25[ER] by 25[ER] *****"
    + f"\n\tCLGAM took on average: {(clgam_end - clgam_start) / glassoregs.shape[0]} seconds"
    + f"\n\tLGAM took on average: {(lgam_end - lgam_start) / glassoregs.shape[0]} seconds"
)
# Out:
# ***** 25[ER] by 25[ER] by 25[ER] by 25[ER] *****
# 	CLGAM took on average: 134.457635474205 seconds
# 	LGAM took on average: 40.384445214271544 seconds
